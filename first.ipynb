# %%
import numpy as np

# a[:2]
# a[:2,1:3] #asdasdasdasd

import matplotlib.pyplot as plt
# %matplotlib inline
# Compute the x and y coordinates for points on a sine curve
x = np.arange(0, 3 * np.pi, 0.1)
y = np.sin(x)
plt.xlabel('time (s)')
plt.ylabel('current (nA)')
plt.title('Gaussian colored noise')
# Plot the points using matplotlib
plt.plot(x, y)
plt.show()  # You must call plt.show() to make graphics appear.

# %%
x = np.arange(-10, 10, 1)
y = 1/(1 + np.exp(-x))
plt.plot(x, y)
plt.show()

# %%
x = np.arange(-10, 10, 1)
y=np.tanh(x)
plt.plot(x, y)
plt.show()

# %%
# Hard-limit transfer function
def hardlim(n):
    if n>=0:
        return 1
    else:
        return 0
# single layer perceptron
def simplelayer(X):
    W=[1,1]
    b=-1/2  #or
#     b=-3/2  #and
    return hardlim(np.dot(X,W)+b)
# tow-layer perceptron : the xor problem
def binarylayer(X):
    W1=[1,1]
    W2=[1,-2]
    b1_1=-1/2
    b1_2=-3/2
    b2_1=-1/2
    y1_1=hardlim(np.dot(X,W1)+b1_1) #or
    y1_2=hardlim(np.dot(X,W1)+b1_2) #and
    X2=[y1_1,y1_2]
    y2_1=hardlim(np.dot(X2,W1)+b2_1) #xor
    return y2_1

# %%
# [0,1] [0,0] [1,0] [1,1]
# simplelayer([1,1])
binarylayer([1,0])
# Out:
# 1

# %% [markdown]
# ## 0.5 ~ "FaceGAN"
#
# ### 0.5.x
#
# * fixed configuration save/load
# * cleaner cli output
# * documentation cleanup
#
#
#
# ### 0.5.0
# * pip package released!
# * Better defaults.  Good variance.  256x256.  The broken images showed up after training for 5 days.
#
#
#
# ### 0.1-0.4
# * Initial private release
#
#
#
# # Quick start
# Inline-style:
# ![alt text](./images/1.png "Logo Title Text 1")

# %% [markdown]
# \begin{align}
# \dot{x} & = \sigma(y-x) \\
# \dot{y} & = \rho x - y - xz \\
# \dot{z} & = -\beta z + xy
# \end{align}
# \begin{equation*}
# \mathbf{V}_1 \times \mathbf{V}_2 =  \begin{vmatrix}
# \mathbf{i} & \mathbf{j} & \mathbf{k} \\
# \frac{\partial X}{\partial u} &  \frac{\partial Y}{\partial u} & 0 \\
# \frac{\partial X}{\partial v} &  \frac{\partial Y}{\partial v} & 0
# \end{vmatrix}
# \end{equation*}

# %% [markdown]
# ##Mini Batch Gradient Descent
